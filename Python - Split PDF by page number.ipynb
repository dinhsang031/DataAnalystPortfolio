# %%
# !pip install PyPDF2
# !pip install reportlab
# !pip install nbconvert

# %%
###PHÂN TÁCH BÁO CÁO CHẤM CÔNG PHÒNG
import os
from PyPDF2 import PdfReader, PdfWriter

def split_pdf(input_path, output_dir, splits):
    with open(input_path, 'rb') as input_pdf:
        pdf_reader = PdfReader(input_pdf)
        for name, split_range in splits.items():
            start_page = split_range[0] - 1
            end_page = split_range[1] if split_range[1] else None

            pdf_writer = PdfWriter()
            for page_num in range(start_page, end_page):
                pdf_writer.add_page(pdf_reader.pages[page_num])

            output_path = os.path.join(output_dir, f'Báo cáo chấm công - {name}.pdf')
            with open(output_path, 'wb') as output_pdf:
                pdf_writer.write(output_pdf)

if __name__ == "__main__":
    #ĐỔI INPUT VÀ OUTPUT
    input_pdf_path = r"C:\Users\Dell03.LAPTOP-PTNNLMOI\Desktop\Báo cáo tuân thủ\Báo cáo chấm công Phòng\Tháng 04\16042024\16042024.pdf"
    output_dir = r"C:\Users\Dell03.LAPTOP-PTNNLMOI\Desktop\Báo cáo tuân thủ\Báo cáo chấm công Phòng\Tháng 04\16042024"

    splits = {
        'HTCNTT': (1, 1),
        'UDPM': (2, 3),
        'Hành chính': (4, 6),
        'HTQT': (7, 7),
        'KTNB': (8, 8),
        'Pháp chế': (9, 9),
        'PTNNL': (10, 11),
        'BHDC': (12, 13),
        'BHGT': (14, 17),
        'BHMDF': (18, 18),
        'BHTH': (19, 19),
        'BHTT': (20, 20),
        'QLNH': (21, 21),
        'MAR': (22, 22),
        'KH': (23, 23),
        'LOG SCM': (24, 25),
        'MHNVL': (27, 27),
        'BHQT': (26, 26),
        'MHTMDV': (28, 28),
        'TMG': (29, 29),
        'BCL': (30, 30),
        'KT': (31, 33),
        'KTQT': (34, 34),
        'KTT': (35, 35),
        'NV': (36, 36),
        'QTNSDA': (37, 37),
        'PTHT': (38, 39),
        'MHDA': (40, 40),
        'KTDA': (41, 41),
        'R&D Gỗ': (42, 42),
        'R&D VLH': (43, 43),
        'R&D Điện': (44, 44),
        'KV': (45, 49),
        'NLX': (50, 50)
    }

    split_pdf(input_pdf_path, output_dir, splits)

# %%
###BÁO CÁO TUÂN THỦ CÔNG TY
import os
from PyPDF2 import PdfReader, PdfWriter

def split_pdf(input_path, output_dir, splits):
    with open(input_path, 'rb') as input_pdf:
        pdf_reader = PdfReader(input_pdf)
        for name, split_range in splits.items():
            start_page = split_range[0] - 1
            end_page = split_range[1] if split_range[1] else None

            pdf_writer = PdfWriter()
            for page_num in range(start_page, end_page):
                pdf_writer.add_page(pdf_reader.pages[page_num])

            output_path = os.path.join(output_dir, f'{name} - Báo cáo tuân thủ.pdf')
            with open(output_path, 'wb') as output_pdf:
                pdf_writer.write(output_pdf)

if __name__ == "__main__":
    #ĐỔI INPUT VÀ OUTPUT
    input_pdf_path = r"C:\Users\Dell03.LAPTOP-PTNNLMOI\Desktop\Báo cáo tuân thủ\Báo cáo tuân thu công ty\Năm 2024\Tháng 4\16042024\16042024.pdf"
    output_dir = r"C:\Users\Dell03.LAPTOP-PTNNLMOI\Desktop\Báo cáo tuân thủ\Báo cáo tuân thu công ty\Năm 2024\Tháng 4\16042024"

    splits = {
        'HO': (1, 1),
        'TTCNTT': (2, 2),
        'SCM': (3, 3),
        'TCKT': (4, 4),
        'TTR&D': (5, 5)
    }

    split_pdf(input_pdf_path, output_dir, splits)
